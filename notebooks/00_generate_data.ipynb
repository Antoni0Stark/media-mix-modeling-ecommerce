# %%
import pandas as pd
import numpy as np

np.random.seed(42)

weeks = pd.date_range(start="2022-01-01", periods=104, freq="W")

data = pd.DataFrame({
    "date": weeks,
    "paid_search_spend": np.random.normal(50000, 8000, size=104),
    "paid_social_spend": np.random.normal(40000, 7000, size=104),
    "display_spend": np.random.normal(20000, 5000, size=104),
    "email_volume": np.random.normal(300000, 40000, size=104)
})

data.to_csv("../data/raw/marketing_data.csv", index=False)
data.head()
# Out:
#         date  paid_search_spend  paid_social_spend  display_spend  \
# 0 2022-01-02       53973.713224       38871.000018   22575.238432
# 1 2022-01-09       48893.885591       42828.355998   39263.657453
# 2 2022-01-16       55181.508305       53203.301308   22854.452553
# 3 2022-01-23       62184.238851       41222.044690   25677.828201
# 4 2022-01-30       48126.773002       41802.852735   24770.008817
#
#     email_volume
# 0  333016.653960
# 1  332540.385440
# 2  352219.152286
# 3  300840.153665
# 4  327278.118852
